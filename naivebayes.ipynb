# %%
import numpy as np
import pandas as pd

# %%
import xlrd
import os

# %%
df=pd.read_excel('survey_dataset.xls')

# %%
def quali_to_numeric(x):
    if x=='SSLC':
        return 1
    if x=='Plus Two':
        return 2
    if x=='Graduation':
        return 3
    if x=='PG':
        return 4
    else :
        return 0
    
def country_to_numeric(x):
    if x=='America':
        return 5
    else:
        return 3

# %%
df['Qualification'] = df['Qualification'].apply(quali_to_numeric)
df['Country'] = df['Country'].apply(country_to_numeric)
df
# Out:
#      Reader_id  Gender  Age  Qualification  Country  Income  \
# 0            1    Male   65              3        5   50000
# 1            2    Male   32              1        3   20000
# 2            3  Female   41              4        5   80000
# 3            4  Female   33              4        5  120000
# 4            5  Female   65              4        3   30000
# 5            6  Female   69              1        3   12000
# 6            7  Female   35              3        3   25000
# 7            8  Female   25              2        3   15000
# 8            9  Female   23              2        3   10000
# 9           10  Female   22              3        3   50000
# 10          11  Female   21              0        3   28000
# 11          12  Female   18              3        3   25000
# 12          13  Female   19              3        3   15000
# 13          14  Female   20              2        3   10000
# 14          15  Female   30              3        3   25000
# ...

# %%
res1=df['Political biasness(1-10)']
res2=res1.append(df['Political biasness(1-10)'])
res3=res2.append(df['Political biasness(1-10)'])
res4=res3.append(df['Political biasness(1-10)'])
res5=res4.append(df['Political biasness(1-10)'])

# %%
res5.columns=['Political biasness(1-10)']
print(res5)
print(res5.columns)
# Out:
# 0      4
# 1      3
# 2      5
# 3      4
# 4      4
# 5      5
# 6      6
# 7      3
# 8      5
# 9      9
# 10     7
# 11     2
# 12     1
# 13     6
# 14     5
# 15     8
# 16     6
# 17     5
# 18     4
# 19     3
# 20     9
# 21     6
# 22     8
# 23     7
# 24     7
# 25     5
# 26     2
# 27     2
# 28     2
# 29     6
#       ..
# 470    5
# 471    9
# 472    8
# 473    8
# 474    6
# 475    3
# 476    3
# 477    3
# 478    7
# 479    6
# 480    7
# 481    5
# 482    2
# 483    3
# 484    3
# 485    6
# 486    7
# 487    9
# 488    5
# 489    5
# 490    5
# 491    7
# 492    6
# 493    5
# 494    2
# 495    3
# 496    3
# 497    6
# 498    7
# 499    9
# Name: Political biasness(1-10), Length: 2500, dtype: int64
# ['Political biasness(1-10)']

# %%
y1=pd.DataFrame([5]*100)
y2=pd.DataFrame([4]*100)
y3=pd.DataFrame([3]*100)
y4=pd.DataFrame([2]*100)
y5=pd.DataFrame([1]*100)

# %%
f1=df[['Age','Income','Qualification','Country']]

# %%
f2=f1.append(f1)
f3=f2.append(f1)
f4=f3.append(f1)
f5=f4.append(f1)

# %%
f5
# Out:
#      Age  Income  Qualification  Country
# 0     65   50000              3        5
# 1     32   20000              1        3
# 2     41   80000              4        5
# 3     33  120000              4        5
# 4     65   30000              4        3
# 5     69   12000              1        3
# 6     35   25000              3        3
# 7     25   15000              2        3
# 8     23   10000              2        3
# 9     22   50000              3        3
# 10    21   28000              0        3
# 11    18   25000              3        3
# 12    19   15000              3        3
# 13    20   10000              2        3
# 14    30   25000              3        3
# 15    41   30000              1        3
# 16    52   12000              3        3
# 17    48   50000              4        3
# 18    52    2000              1        3
# 19    18   10000              1        3
# 20    19   12000              2        3
# 21    32   20000              4        3
# ...

# %%
result_matrix=res5
result_matrix.columns=['Political biasness(1-10)']
print(result_matrix)
# Out:
# 0      4
# 1      3
# 2      5
# 3      4
# 4      4
# 5      5
# 6      6
# 7      3
# 8      5
# 9      9
# 10     7
# 11     2
# 12     1
# 13     6
# 14     5
# 15     8
# 16     6
# 17     5
# 18     4
# 19     3
# 20     9
# 21     6
# 22     8
# 23     7
# 24     7
# 25     5
# 26     2
# 27     2
# 28     2
# 29     6
#       ..
# 470    5
# 471    9
# 472    8
# 473    8
# 474    6
# 475    3
# 476    3
# 477    3
# 478    7
# 479    6
# 480    7
# 481    5
# 482    2
# 483    3
# 484    3
# 485    6
# 486    7
# 487    9
# 488    5
# 489    5
# 490    5
# 491    7
# 492    6
# 493    5
# 494    2
# 495    3
# 496    3
# 497    6
# 498    7
# 499    9
# Name: Political biasness(1-10), Length: 2500, dtype: int64

# %%
#from sklearn.preprocessing import MinMaxScaler



#scaler = MinMaxScaler()
numerical = ['Age']

features_minmax_transform = pd.DataFrame(data = f5)
features_minmax_transform[numerical] = f5[numerical]
features_minmax_transform
# Out:
#      Age  Income  Qualification  Country
# 0     65   50000              3        5
# 1     32   20000              1        3
# 2     41   80000              4        5
# 3     33  120000              4        5
# 4     65   30000              4        3
# 5     69   12000              1        3
# 6     35   25000              3        3
# 7     25   15000              2        3
# 8     23   10000              2        3
# 9     22   50000              3        3
# 10    21   28000              0        3
# 11    18   25000              3        3
# 12    19   15000              3        3
# 13    20   10000              2        3
# 14    30   25000              3        3
# 15    41   30000              1        3
# 16    52   12000              3        3
# 17    48   50000              4        3
# 18    52    2000              1        3
# 19    18   10000              1        3
# 20    19   12000              2        3
# 21    32   20000              4        3
# ...

# %%
features_final = pd.get_dummies(features_minmax_transform)
display(features_final.head(5))
encoded = list(features_final.columns)
#print ("{} total features after one-hot encoding.").format(len(encoded))

# The following line shows the encoded feature names
#print ("encoded")
# Out:
#    Age  Income  Qualification  Country
# 0   65   50000              3        5
# 1   32   20000              1        3
# 2   41   80000              4        5
# 3   33  120000              4        5
# 4   65   30000              4        3

# %%
features_final
# Out:
#      Age  Income  Qualification  Country
# 0     65   50000              3        5
# 1     32   20000              1        3
# 2     41   80000              4        5
# 3     33  120000              4        5
# 4     65   30000              4        3
# 5     69   12000              1        3
# 6     35   25000              3        3
# 7     25   15000              2        3
# 8     23   10000              2        3
# 9     22   50000              3        3
# 10    21   28000              0        3
# 11    18   25000              3        3
# 12    19   15000              3        3
# 13    20   10000              2        3
# 14    30   25000              3        3
# 15    41   30000              1        3
# 16    52   12000              3        3
# 17    48   50000              4        3
# 18    52    2000              1        3
# 19    18   10000              1        3
# 20    19   12000              2        3
# 21    32   20000              4        3
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(features_final, res5, train_size=0.80,random_state=1)
# Out:
# /home/devika/.local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2069: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
X_train
# Out:
#      Age  Income  Qualification  Country
# 418   27   10000              1        3
# 199   44    8000              3        3
# 139   44   22000              3        3
# 2     41   80000              4        5
# 352   43   35000              3        3
# 495   26    5000              4        3
# 123   25   42000              3        3
# 287   32    3000              1        3
# 316   52    8000              2        3
# 421   34    8000              1        3
# 491   31   30000              4        3
# 179   23    5000              3        3
# 181   21   12000              3        3
# 146   52   22000              3        3
# 204   20   10000              2        3
# 210   42   30000              3        3
# 201   41   40000              3        3
# 186   30   20000              3        3
# 385   47   20000              4        3
# 249   25   25000              3        3
# 165   32   10000              3        3
# 16    52   12000              3        3
# ...

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = gnb.predict(X_test)
Accuracy=metrics.accuracy_score(y_test, y_pred)
Accuracy
# Out:
# 0.186

# %%
predicted= gnb.predict([[55,25000,4,5]])

# %%
#predicted

# %%
print ("The reader political biasness is",predicted[0])
# Out:
# The reader political biasness is 4

# %%
if predicted[0]<5 :
    print("Right biased")
else :
    print("Left biased")
# Out:
# Right biased
